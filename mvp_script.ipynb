# %%
# %reset -fs

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer

# %%
df = pd.read_csv('sotu_texts.csv')
df
# Out:
#              President  Year  \
# 0    George Washington  1790
# 1    George Washington  1790
# 2    George Washington  1791
# 3    George Washington  1792
# 4    George Washington  1793
# ..                 ...   ...
# 215       Barack Obama  2016
# 216       Donald Trump  2017
# 217       Donald Trump  2018
# 218       Donald Trump  2019
# 219          Joe Biden  2022
#
#                                                 Title  \
# 0                    First State of the Union Address
# 1                   Second State of the Union Address
# 2                    Third State of the Union Address
# 3                   Fourth State of the Union Address
# 4                    Fifth State of the Union Address
# ..                                                ...
# 215  Barack Obama's Eighth State of the Union Address
# 216   Donald Trump's First State of the Union Address
# 217  Donald Trump's Second State of the Union Address
# 218   Donald Trump's Third State of the Union Address
# 219      Joe Biden's First State of The Union Address
#
#                                                   Text
# 0    ['I embrace with great satisfaction the opport...
# 1    ['Fellow-Citizens of the Senate and the House ...
# 2    ['Fellow-Citizens of the Senate and the House ...
# 3    ['Fellow-Citizens of the Senate and of the Hou...
# 4    ['Fellow Citizens of the Senate and of the Hou...
# ..                                                 ...
# 215  ['Mr. Speaker, Mr. Vice President, Members of ...
# 216  ['Mr. Speaker, Mr. Vice President, Members of ...
# 217  ['Mr. Speaker, Mr. Vice President, Members of ...
# 218  ['Madam Speaker, Mr. Vice President, Members o...
# 219  ['Madam Speaker, Madam Vice President, our Fir...
#
# [220 rows x 4 columns]

# %%
docs = df.Text

# %%
vec = CountVectorizer()

# %%
doc_terms = vec.fit_transform(docs)
doc_terms.toarray()
# Out:
# array([[ 0,  0,  0, ...,  0,  0,  0],
#        [ 0,  2,  0, ...,  0,  0,  0],
#        [ 0,  5,  0, ...,  0,  0,  0],
#        ...,
#        [ 0,  9,  0, ...,  0,  0,  0],
#        [ 0, 12,  0, ...,  0,  0,  0],
#        [ 0, 12,  0, ...,  0,  0,  0]])

# %%
pd.unique(doc_terms.toarray().reshape(-1))
# Out:
# array([   0,    1,    3,    2,    5,   40,    4,    9,   20,   12,    8,
#          10,    7,   61,   15,   94,   56,   18,   14,   11,    6,   45,
#          19,   16,   27,   22,   89,   17,  123,   49,   13,   73,   29,
#          34,   25,  156,   33,  237,   88,   38,   23,   26,   28,   30,
#          48,  140,   24,  196,   31,   43,  133,  181,   74,   21,   86,
#          36,   32,  188,   39,  274,  138,  131,  175,   64,   41,   35,
#          67,  194,  263,  112,  125,  183,   76,   91,  152,  217,   79,
#          53,  107,  151,   50,   87,  126,   63,  100,   62,  179,   47,
#         220,  136,   81,   46,  127,  176,   66,   92,  184,   70,   55,
#         137,   96,   37,   60,  189,  235,   95,   83,   51,  153,  225,
#         115,   44,  178,  159,  249,   93,  205,  116,   59,  198,  316,
#         199,  328,   98,  108,  233,  356,   80,  219,  355,  111,  103,
#         232,   58,  432,  168,  139,  400,  165,   42,  122,   65,   99,
#         238,  445,  203,   71,  106,   90,  321,   57,  174,   52,  130,
#          85,  337,   82,  570,  230,   69,  437,  186,  208,  395,  636,
#         216,   75,  284,  449,  757,  299,  102,  323,   84,  160,  766,
#          97,  973,  287,  256,  149,   54,  624,   72,  822,  280,  215,
#         582,   68,  124,  649,  829,  229,  300,  171,  104,  231,  129,
#         653,  950,   78,  420,  456,  118,  110,  324,  147,  887,  202,
#        1396,  625,  201,  222,  416,  285,  247,   77,  473,  114,  117,
#         747,  310,  241,  144,  105,  475,  854,  427,  113,  279,  101,
#         169,  778,  212, 1333,  539,  134,  143,  644,  170, 1116,  446,
#         383,  167,  150,  771, 1302,  489,  526,  783,  332,  109,  260,
#         190,  520,  827,  336,  240,  192,  536,  751,  319,  281,  135,
#         211,  593,  889,  388,  537,  226,  191,  302, 1006, 1529,  588,
#         633,  141,  206,  239,  164,  342,  158, 1113,  120, 1621,  645,
#         627,  228,  173,  933, 1426,  597,  850,  250,  408,  254, 1373,
#         187, 2182,  651,  268,  519,  746,  305,  132,  494,  759,  307,
#         484,  121,  872, 1299,  461,  317,  185,  639,  980,  401,  365,
#         652,  930,  371,  334,  931,  415,  266,  875, 1236,  426,  363,
#        1088,  398,  166,  119, 1217,  142,  523,  514,  177,  905, 1472,
#         243,  641, 1183,  443,  157,  291,  762, 1345,  499,  628,  267,
#         358,  589,  209,  346,  558,  195,  569,  128,  640, 1001,  290,
#         483,  727,  210,  162, 1029,  380,  967,  245,  488,  777,  298,
#         572,  845,  680,  312,  180,  715, 1071,  283,  682,  959,  327,
#         207,  676,  915,  385,  798, 1123,  441,  479,  737,  389,  242,
#        1137,  387,  161,  545,  879,  382,  270,  787, 1196,  491,  306,
#         948, 1418,  341,  148,  885,  154, 1295,  381,  265,  631,  937,
#         521,  780,  223,  606,  906,  236,  686,  248,  458, 1305, 1921,
#         586,  163,  329, 1074, 1494,  450,  197,  309,  468,  531,  890,
#        1258,  386,  451,  296,  866,  172, 1282,  390,  706, 1130,  361,
#         502,  345, 1011, 1622,  503,  835, 1348,  405,  264,  816, 1185,
#         370, 1036, 1520,  457,  533,  145,  369,  840, 1173,  577,  343,
#         919, 1321,  480,  368,  742, 1142,  410,  663,  234,  374, 1310,
#        2073,  620,  825,  262,  538, 1463,  200, 2294,  695,  477,  961,
#        1586,  430,  634,  308,  474,  271,  995, 1710,  671,  273,  786,
#         303,  504,  352,  932,  146, 1527,  505,  916, 1428,  575,  725,
#         259,  252,  613,  362, 1307, 2126,  911,  292,  349, 1219,  269,
#        2010,  869,  417,  660,  314,  315, 2432,  945,  204,  592,  972,
#        1718,  648,  482, 1446,  699,  282, 1760,  367, 2880,  754,  224,
#        2248,  714,  789,  673, 1580, 2491,  808,  227,  155,  275,  404,
#         399,  376,  418,  297,  463,  364,  496,  335,  726,  601,  261,
#         373,  619,  626,  921,  340,  378,  431,  221,  351,  213,  322,
#         294,  377,  646,  898,  490, 1198, 2032,  697,  276,  325,  258,
#         347,  218,  723,  402,  486,  409,  313,  440,  608,  278,  318,
#         424,  251,  295,  288,  244,  333,  182, 1358,  413,  330,  836,
#        1298,  392,  272, 2360, 1200,  320,  193,  246,  326,  301,  350,
#         403,  304,  407,  253,  338,  293,  214])

# %%
vec.vocabulary_
# Out:
# {'embrace': 8518,
#  'with': 26389,
#  'great': 10863,
#  'satisfaction': 21496,
#  'the': 24098,
#  'opportunity': 17529,
#  'which': 26259,
#  'now': 16691,
#  'presents': 19040,
#  'itself': 13150,
#  'of': 17407,
#  'congratulating': 5819,
#  'you': 26639,
#  'on': 17481,
#  'present': 19034,
#  'favourable': 9645,
#  'prospects': 19411,
#  'our': 17647,
#  'public': 19513,
#  'affairs': 2012,
#  'recent': 20009,
#  'accession': 1685,
#  'important': 12001,
#  'state': 22931,
#  'north': 16630,
#  'carolina': 4591,
#  'to': 24341,
#  'constitution': 5957,
#  'united': 25271,
#  'states': 22940,
#  'official': 17429,
#  'information': 12452,
#  'has': 11212,
#  'been': 3556,
#  'received': 20003,
#  'rising': 21138,
#  'credit': 6443,
#  'and': 2447,
#  'respectability': 20824,
#  'country': 6346,
#  'general': 10568,
#  'increasing': 12210,
#  'good': 10729,
#  'will': 26325,
#  'towards': 24444,
#  'government': 10759,
#  'union': 25261,
#  'concord': 5705,
#  'peace': 18167,
#  'plenty': 18641,
#  'we': 26134,
#  'are': 2776,
#  'blessed': 3863,
#  'circumstances': 5064,
#  'auspicious': 3169,
#  'in': 12086,
#  'an': 2421,
#  'eminent': 8547,
#  'degree': 7002,
#  'national': 15525,
#  'prosperity': 19415,
#  'resuming': 20894,
#  'your': 26645,
#  'consultations': 5988,
#  'for': 10044,
#  'cannot': 4511,
#  'but': 4384,
#  'derive': 7242,
#  'encouragement': 8637,
#  'from': 10353,
#  'reflection': 20251,
#  'that': 24096,
#  'measures': 14622,
#  'last': 13606,
#  'session': 21942,
#  'have': 11243,
#  'as': 2893,
#  'satisfactory': 21498,
#  'constituents': 5952,
#  'novelty': 16687,
#  'difficulty': 7472,
#  'work': 26456,
#  'allowed': 2275,
#  'hope': 11591,
#  'still': 23053,
#  'further': 10446,
#  'u200brealize': 24857,
#  'their': 24104,
#  'expectations': 9276,
#  'secure': 21750,
#  'blessings': 3865,
#  'gracious': 10773,
#  'providence': 19465,
#  'placed': 18567,
#  'within': 26404,
#  'reach': 19855,
#  'course': 6361,
#  'call': 4450,
#  'cool': 6178,
#  'deliberate': 7021,
#  'exertion': 9223,
#  'patriotism': 18120,
#  'firmness': 9865,
#  'wisdom': 26375,
#  'among': 2398,
#  'many': 14405,
#  'interesting': 12797,
#  'objects': 17307,
#  'engage': 8707,
#  'attention': 3111,
#  'providing': 19473,
#  'common': 5477,
#  'defence': 6936,
#  'merit': 14746,
#  'particular': 18040,
#  'regard': 20303,
#  'be': 3513,
#  'prepared': 19006,
#  'war': 26039,
#  'is': 13103,
#  'one': 17483,
#  'most': 15204,
#  'effectual': 8361,
#  'means': 14612,
#  'preserving': 19046,
#  'free': 10282,
#  'people': 18254,
#  'ought': 17644,
#  'not': 16647,
#  'only': 17490,
#  'armed': 2815,
#  'disciplined': 7625,
#  'end': 8652,
#  'uniform': 25230,
#  'well': 26206,
#  'digested': 7482,
#  'plan': 18581,
#  'requisite': 20728,
#  'safety': 21382,
#  'interest': 12795,
#  'require': 20722,
#  'they': 24144,
#  'should': 22165,
#  'promote': 19312,
#  'such': 23408,
#  'manufactories': 14393,
#  'tend': 23986,
#  'render': 20554,
#  'them': 24106,
#  'independent': 12253,
#  'others': 17637,
#  'essential': 9000,
#  'particularly': 18044,
#  'military': 14849,
#  'supplies': 23561,
#  'proper': 19354,
#  'establishment': 9008,
#  'troops': 24713,
#  'may': 14573,
#  'deemed': 6904,
#  'indispensible': 12303,
#  'entitled': 8839,
#  'mature': 14555,
#  'consideration': 5899,
#  'arrangements': 2842,
#  'made': 14215,
#  'respecting': 20829,
#  'it': 13139,
#  'u200bimportance': 24854,
#  'conciliate': 5689,
#  'comfortable': 5406,
#  'support': 23564,
#  'officers': 17427,
#  'soldiers': 22538,
#  'due': 8196,
#  'oeconomy': 17406,
#  'there': 24123,
#  'was': 26084,
#  'reason': 19935,
#  'pacific': 17872,
#  'adopted': 1936,
#  'certain': 4757,
#  'hostile': 11640,
#  'tribes': 24659,
#  'indians': 12267,
#  'would': 26508,
#  'relieved': 20457,
#  'inhabitants': 12487,
#  'southern': 22633,
#  'western': 26221,
#  'frontiers': 10358,
#  'depredations': 7207,
#  'percieve': 18275,
#  'contained': 6008,
#  'papers': 17958,
#  'shall': 22011,
#  'direct': 7535,
#  'laid': 13550,
#  'before': 3567,
#  'comprehending': 5618,
#  'communication': 5490,
#  'commonwealth': 5481,
#  'virginia': 25878,
#  'afford': 2047,
#  'protection': 19428,
#  'those': 24184,
#  'parts': 18062,
#  'if': 11809,
#  'necessary': 15888,
#  'punish': 19543,
#  'aggressors': 2104,
#  'interests': 12799,
#  'intercourse': 12786,
#  'other': 17636,
#  'nations': 15533,
#  'facilitated': 9480,
#  'by': 4401,
#  'provisions': 19482,
#  'enable': 8606,
#  'me': 14600,
#  'fulfill': 10399,
#  'my': 15340,
#  'duty': 8231,
#  'respect': 20823,
#  'manner': 14380,
#  'conducive': 5736,
#  'this': 24167,
#  'compensation': 5540,
#  'persons': 18388,
#  'who': 26280,
#  'employed': 8580,
#  'according': 1717,
#  'nature': 15549,
#  'appointments': 2668,
#  'defined': 6968,
#  'law': 13653,
#  'competent': 5546,
#  'fund': 10420,
#  'u200bdesignated': 24853,
#  'defraying': 6987,
#  'expenses': 9302,
#  'incident': 12136,
#  'conduct': 5737,
#  'foreign': 10089,
#  'various': 25708,
#  'considerations': 5900,
#  'also': 2303,
#  'expedient': 9281,
#  'terms': 24036,
#  'foreigners': 10091,
#  'admitted': 1919,
#  'rights': 21108,
#  'citizens': 5072,
#  'speedily': 22738,
#  'ascertained': 2905,
#  'rule': 21303,
#  'naturalization': 15542,
#  'uniformity': 25233,
#  'currency': 6613,
#  'weights': 26194,
#  'object': 17298,
#  'importance': 12000,
#  'am': 2331,
#  'persuaded': 18392,
#  'duly': 8204,
#  'attended': 3108,
#  'advancement': 1957,
#  'agriculture': 2130,
#  'commerce': 5448,
#  'manufactures': 14399,
#  'all': 2229,
#  'trust': 24743,
#  'need': 15900,
#  'recommendation': 20066,
#  'forbear': 10049,
#  'intimating': 12897,
#  'expediency': 9280,
#  'giving': 10671,
#  'introduction': 12930,
#  'new': 16028,
#  'useful': 25592,
#  'inventions': 12974,
#  'abroad': 1610,
#  'exertions': 9224,
#  'skill': 22355,
#  'genius': 10596,
#  'producing': 19219,
#  'at': 3053,
#  'home': 11534,
#  'facilitating': 9482,
#  'between': 3742,
#  'distant': 7880,
#  'post': 18817,
#  'office': 17424,
#  'roads': 21166,
#  'u200bnor': 24855,
#  'less': 13789,
#  'agree': 2120,
#  'opinion': 17518,
#  'nothing': 16658,
#  'can': 4480,
#  'better': 3736,
#  'deserve': 7268,
#  'patronage': 18127,
#  'than': 24087,
#  'promotion': 19317,
#  'science': 21611,
#  'literature': 13976,
#  'knowledge': 13481,
#  'every': 9081,
#  'surest': 23589,
#  'basis': 3477,
#  'happiness': 11148,
#  'receive': 20002,
#  'impression': 12041,
#  'so': 22496,
#  'immediately': 11888,
#  'sense': 21864,
#  'community': 5496,
#  'ours': 17648,
#  'proportionably': 19369,
#  'security': 21758,
#  'contributes': 6101,
#  'ways': 26133,
#  'convincing': 6162,
#  'entrusted': 8857,
#  'administration': 1899,
#  'valuable': 25669,
#  'best': 3720,
#  'answered': 2524,
#  'enlightened': 8757,
#  'confidence': 5764,
#  'teaching': 23902,
#  'themselves': 24109,
#  'know': 13478,
#  'value': 25673,
#  'own': 17854,
#  'discern': 7615,
#  'provide': 19463,
#  'against': 2074,
#  'invasions': 12965,
#  'distinguish': 7893,
#  'oppression': 17542,
#  'exercise': 9216,
#  'lawful': 13655,
#  'authority': 3191,
#  'burthens': 4364,
#  'proceeding': 19187,
#  'disregard': 7839,
#  'convenience': 6127,
#  'resulting': 20889,
#  'inevitable': 12377,
#  'exigencies': 9244,
#  'society': 22515,
#  'discriminate': 7679,
#  'spirit': 22765,
#  'liberty': 13850,
#  'licentiousness': 13860,
#  'cherishing': 4928,
#  'first': 9868,
#  'avoiding': 3258,
#  'uniting': 25273,
#  'speedy': 22741,
#  'temperate': 23961,
#  'vigilence': 25840,
#  'encroachments': 8647,
#  'inviolable': 13004,
#  'laws': 13665,
#  'whether': 26258,
#  'desirable': 7288,
#  'promoted': 19313,
#  'affording': 2051,
#  'aids': 2139,
#  'seminaries': 21837,
#  'learning': 13704,
#  'already': 2301,
#  'established': 9005,
#  'institution': 12673,
#  'u200bof': 24856,
#  'university': 25281,
#  'or': 17556,
#  'any': 2585,
#  'expedients': 9282,
#  'worthy': 26507,
#  'place': 18566,
#  'deliberations': 7026,
#  'legislature': 13754,
#  'saw': 21521,
#  'peculiar': 18194,
#  'pleasure': 18629,
#  'close': 5205,
#  'resolution': 20807,
#  'entered': 8815,
#  'into': 12903,
#  'expressive': 9387,
#  'adequate': 1862,
#  'provision': 19478,
#  'matter': 14548,
#  'high': 11436,
#  'honor': 11575,
#  'sentiment': 21882,
#  'entirely': 8835,
#  'concur': 5708,
#  'perfect': 18281,
#  'endeavors': 8662,
#  'devise': 7405,
#  'truly': 24738,
#  'consistent': 5912,
#  'add': 1841,
#  'equal': 8903,
#  'reliance': 20449,
#  'chearful': 4892,
#  'co': 5234,
#  'operation': 17510,
#  'branch': 4103,
#  'superfluous': 23506,
#  'specify': 22710,
#  'inducements': 12335,
#  'measure': 14619,
#  'character': 4832,
#  'permanent': 18322,
#  'obviously': 17370,
#  'deeply': 6913,
#  'concerned': 5679,
#  'explicit': 9334,
#  'sanction': 21449,
#  'declaration': 6858,
#  'directed': 7536,
#  'lay': 13672,
#  'respectively': 20831,
#  'estimates': 9018,
#  'recommended': 20069,
#  'convey': 6147,
#  'welfare': 26204,
#  'cares': 4580,
#  'efforts': 8375,
#  'pleasing': 18628,
#  'tho': 24169,
#  'arduous': 2775,
#  'task': 23870,
#  'ensuring': 8804,
#  'fellow': 9703,
#  'right': 21098,
#  'expect': 9272,
#  'efficient': 8370,
#  'senate': 21846,
#  'house': 11657,
#  'representatives': 20672,
#  'meeting': 14666,
#  'again': 2073,
#  'feel': 9686,
#  'much': 15256,
#  'being': 3611,
#  'able': 1576,
#  'repeat': 20621,
#  'congratulations': 5821,
#  'favorable': 9636,
#  'continue': 6063,
#  'abundant': 1647,
#  'fruits': 10379,
#  'another': 2521,
#  'year': 26605,
#  'flourishing': 9976,
#  'progress': 19270,
#  'witnessed': 26410,
#  'considerable': 5894,
#  'rise': 21135,
#  'american': 2378,
#  'stock': 23081,
#  'revenues': 20980,
#  'allotted': 2268,
#  'purposes': 19588,
#  'productive': 19223,
#  'beyond': 3748,
#  'calculations': 4440,
#  'were': 26216,
#  'regulated': 20347,
#  'latter': 13627,
#  'circumstance': 5063,
#  'more': 15171,
#  'proof': 19338,
#  'fertility': 9732,
#  'resources': 20822,
#  'assures': 3031,
#  'us': 25585,
#  'increase': 12207,
#  'let': 13802,
#  'bears': 3529,
#  'honorable': 11576,
#  'testimony': 24070,
#  'integrity': 12737,
#  'mercantile': 14723,
#  'marine': 14432,
#  'part': 18020,
#  'punctuality': 19540,
#  'former': 10151,
#  'discharging': 7622,
#  'engagements': 8710,
#  'exemplary': 9203,
#  'conformity': 5796,
#  'powers': 18871,
#  'vested': 25773,
#  'acts': 1818,
#  'loan': 14012,
#  '000': 1,
#  'florins': 9969,
#  'toward': 24443,
#  'some': 22574,
#  'provisional': 19479,
#  'had': 11056,
#  'previously': 19103,
#  'taken': 23802,
#  'completed': 5575,
#  'holland': 11524,
#  'celerity': 4708,
#  'filled': 9803,
#  'considering': 5902,
#  'ordinary': 17575,
#  'demand': 7062,
#  'borrowing': 4032,
#  'created': 6425,
#  'situation': 22331,
#  'europe': 9044,
#  'give': 10665,
#  'reasonable': 19936,
#  'execution': 9197,
#  'proceed': 19185,
#  'advantage': 1960,
#  'success': 23390,
#  'secretary': 21735,
#  'treasury': 24624,
#  'directions': 7539,
#  'communicate': 5487,
#  'particulars': 18045,
#  'precise': 18928,
#  'since': 22293,
#  'sessions': 21943,
#  'communications': 5491,
#  'appears': 2628,
#  'district': 7924,
#  'kentucky': 13392,
#  'concurred': 5709,
#  'propositions': 19383,
#  'consequence': 5879,
#  'become': 3547,
#  'distinct': 7886,
#  'member': 14688,
#  'case': 4620,
#  'congress': 5825,
#  'added': 1842,
#  'application': 2655,
#  'cause': 4667,
#  'very': 25769,
#  'transaction': 24523,
#  'liberality': 13836,
#  'harmony': 11185,
#  'conducted': 5738,
#  'found': 10207,
#  'do': 7983,
#  'both': 4044,
#  'parties': 18047,
#  'sentiments': 21886,
#  'warm': 26052,
#  'attachment': 3083,
#  'its': 13149,
#  'expressed': 9382,
#  'fail': 9505,
#  'affectionate': 2018,
#  'concern': 5678,
#  'impressions': 12042,
#  'under': 25020,
#  'decide': 6841,
#  'submitted': 23312,
#  'heretofore': 11391,
#  'known': 13482,
#  'frequent': 10316,
#  'incursion': 12231,
#  'frontier': 10357,
#  'settlements': 21954,
#  'banditti': 3384,
#  'northwest': 16639,
#  'side': 22220,
#  'ohio': 17447,
#  'these': 24142,
#  'dwelling': 8237,
#  'near': 15873,
#  'wabash': 25977,
#  'late': 13612,
#  'active': 1811,
#  'emboldened': 8517,
#  'impunity': 12078,
#  'crimes': 6474,
#  'aided': 2136,
#  'neighboring': 15943,
#  'could': 6307,
#  'seduced': 21765,
#  'join': 13245,
#  'hostilities': 11642,
#  'retreat': 20938,
#  'prisoners': 19149,
#  'plunder': 18659,
#  'instead': 12655,
#  'listening': 13966,
#  'humane': 11693,
#  'invitations': 13009,
#  'overtures': 17835,
#  'renewed': 20568,
#  'violences': 25873,
#  'fresh': 10319,
#  'alacrity': 2176,
#  'greater': 10864,
#  'effect': 8354,
#  'lives': 14001,
#  'number': 17151,
#  'thus': 24250,
#  'sacrificed': 21359,
#  'peculiarly': 18197,
#  'shocking': 22128,
#  'whilst': 26262,
#  'carried': 4599,
#  'deplorable': 7165,
#  'captivity': 4553,
#  'aggravated': 2087,
#  'provocations': 19486,
#  'rendered': 20555,
#  'sensible': 21869,
#  'capable': 4525,
#  'punishing': 19547,
#  'disposed': 7812,
#  'reward': 21043,
#  'attachments': 3084,
#  'effected': 8355,
#  'defensive': 6949,
#  'became': 3543,
#  'put': 19608,
#  'force': 10059,
#  'act': 1805,
#  'empowers': 8596,
#  'president': 19050,
#  'out': 17652,
#  'militia': 14851,
#  'accordingly': 1718,
#  'authorized': 3195,
#  'expedition': 9287,
#  'regular': 20340,
#  'quarter': 19648,
#  'combined': 5395,
#  'drafts': 8099,
#  'sufficient': 23429,
#  'event': 9067,
#  'yet': 26625,
#  'unknown': 25289,
#  'statement': 22937,
#  'founded': 10210,
#  'estimate': 9016,
#  'expense': 9301,
#  'disturbed': 7931,
#  'critical': 6491,
#  'posture': 18838,
#  'maritime': 14438,
#  'make': 14285,
#  'thankful': 24090,
#  'enjoyed': 8745,
#  'reminds': 20510,
#  'same': 21434,
#  'time': 24293,
#  'circumspection': 5062,
#  'becomes': 3548,
#  'preserve': 19043,
#  'requires': 20726,
#  'overlook': 17781,
#  'tendency': 23989,
#  'even': 9063,
#  'preparations': 19003,
#  'abridge': 1605,
#  'thereby': 24127,
#  'least': 13712,
#  'enhance': 8734,
#  'price': 19112,
#  'transporting': 24588,
#  'productions': 19222,
#  'markets': 14447,
#  'recommend': 20065,
#  'serious': 21917,
#  'reflections': 20252,
#  'how': 11672,
#  'far': 9574,
#  'what': 26231,
#  'mode': 15050,
#  'guard': 10979,
#  'embarrassments': 8493,
#  'contingencies': 6054,
#  'encouragements': 8638,
#  'navigation': 15568,
#  'dependent': 7151,
#  'bottoms': 4052,
#  'moments': 15098,
#  'fisheries': 9874,
#  'transportation': 24584,
#  'produce': 19214,
#  'offer': 17420,
#  'guarding': 10984,
#  'ourselves': 17649,
#  'evil': 9094,
#  'seems': 21785,
#  'trade': 24474,
#  'belongs': 3645,
#  'mediterranean': 14661,
#  'unite': 25270,
#  'rendering': 20556,
#  'distressful': 7912,
#  'think': 24153,
#  'misemployed': 14967,
#  'lead': 13682,
#  'relief': 20454,
#  'passed': 18070,
#  'judiciary': 13296,
#  'system': 23755,
#  'opened': 17500,
#  'doors': 8058,
#  'justice': 13335,
#  'descriptions': 7259,
#  'consider': 5893,
#  'improvements': 12061,
#  'process': 19190,
#  'sentences': 21879,
#  'issuing': 13134,
#  'federal': 9669,
#  'courts': 6371,
#  'through': 24232,
#  'merchants': 14730,
#  'sea': 21671,
#  'men': 14702,
#  'called': 4451,
#  'appointment': 2667,
#  'consuls': 5985,
#  'countries': 6345,
#  'regulate': 20346,
#  'jurisdiction': 13324,
#  'functions': 10419,
#  'permitted': 18332,
#  'either': 8394,
#  'express': 9381,
#  'convention': 6132,
#  'friendly': 10334,
#  'indulgence': 12343,
#  'places': 18570,
#  'residence': 20781,
#  'consular': 5982,
#  'too': 24388,
#  'his': 11477,
#  'christian': 5014,
#  'majesty': 14279,
#  'stipulated': 23069,
#  'cases': 4624,
#  'aid': 2135,
#  'here': 11384,
#  'legislative': 13750,
#  'carry': 4604,
#  'stipulations': 23073,
#  'full': 10404,
#  'mint': 14916,
#  'standards': 22902,
#  'subjects': 23297,
#  'presume': 19068,
#  'resume': 20891,
#  'abundantly': 1648,
#  'urged': 25577,
#  'ngentlemen': 16161,
#  'sufficiency': 23428,
#  'appropriated': 2708,
#  'leaves': 13717,
#  'no': 16502,
#  'doubt': 8071,
#  'residuary': 20789,
#  'commensurate': 5440,
#  'faith': 9520,
#  'stands': 22908,
#  'pledged': 18632,
#  'allow': 2271,
#  'moreover': 15172,
#  'favorite': 9641,
#  'policy': 18714,
#  'merely': 14738,
#  'payment': 18158,
#  'debt': 6811,
#  'funded': 10424,
#  'fast': 9605,
#  'growing': 10948,
#  'permit': 18330,
#  'exonerate': 9257,
#  'principal': 19132,
#  'appropriation': 2713,
#  'land': 13561,
#  'explains': 9329,
#  'dispositions': 7817,
#  'subject': 23293,
#  'sooner': 22591,
#  'contribute': 6099,
#  'along': 2296,
#  'actual': 1819,
#  'reduction': 20187,
#  'salutary': 21421,
#  'pursuing': 19598,
#  'weighty': 26195,
#  'business': 4375,
#  'indulge': 12341,
#  'fullest': 10406,
#  'persuasion': 18395,
#  'consultation': 5987,
#  'equally': 8913,
#  'marked': 14440,
#  'animated': 2479,
#  'love': 14123,
#  'whatever': 26232,
#  'cooperation': 6189,
#  'undiminished': 25093,
#  'zeal': 26660,
#  'inspire': 12636,
#  'happy': 11149,
#  'successful': 23392,
#  'respective': 20830,
#  'trusts': 24749,
#  'instrumental': 12688,
#  'promoting': 19316,
#  'george': 10614,
#  'washington': 26089,
#  'meet': 14665,
#  'upon': 25557,
#  'occasion': 17371,
#  'feelings': 9688,
#  'naturally': 15548,
#  'inspired': 12637,
#  'strong': 23223,
#  'prosperous': 19416,
#  'situations': 22332,
#  'labors': 13526,
#  'just': 13334,
#  'commenced': 5430,
#  'guidance': 11003,
#  'prudent': 19499,
#  'patriotic': 18118,
#  'issue': 13131,
#  'stability': 22849,
#  'numerous': 17160,
#  'providential': 19467,
#  'grateful': 10835,
#  'acknowledgments': 1776,
#  'abundance': 1646,
#  'rewarded': 21044,
#  'industry': 12359,
#  'husbandman': 11751,
#  'escape': 8978,
#  'recollection': 20061,
#  'observations': 17332,
#  'satisfied': 21499,
#  'progressive': 19275,
#  'tracing': 24464,
#  'causes': 4669,
#  'remarked': 20491,
#  'effects': 8360,
#  'revival': 21017,
#  'private': 19153,
#  'eminently': 8548,
#  'contributed': 6100,
#  'observed': 17335,
#  'decisive': 6851,
#  'proofs': 19339,
#  'reputation': 20716,
#  'nation': 15524,
#  'nevertheless': 16021,
#  'confirmation': 5776,
#  'disclosed': 7633,
#  'several': 21966,
#  'rapid': 19808,
#  'subscriptions': 23328,
#  'bank': 3395,
#  'sum': 23460,
#  'subscribed': 23322,
#  'single': 22302,
#  'day': 6753,
#  'striking': 23205,
#  'evidences': 9090,
#  'resource': 20819,
#  'interval': 12880,
#  'recess': 20013,
#  'paid': 17895,
#  'different': 7465,
#  'specially': 22699,
#  'provided': 19464,
#  'resolutions': 20808,
#  'defense': 6945,
#  'accomplish': 1708,
#  'principles': 19138,
#  'primary': 19126,
#  'wish': 26380,
#  'treaties': 24628,
#  'provisionally': 19480,
#  'concluded': 5696,
#  'used': 25590,
#  'attach': 3079,
#  'wavering': 26128,
#  'confirm': 5775,
#  'friendship': 10336,
#  'description': 7258,
#  'pacification': 17873,
#  'desired': 7293,
#  'moderation': 15059,
#  'having': 11248,
#  'proved': 19459,
#  'unsuccessful': 25467,
#  'convince': 6159,
#  'refractory': 20269,
#  'power': 18864,
#  'offensive': 17417,
#  'operations': 17512,
#  'therefore': 24129,
#  'however': 11674,
#  'consistently': 5913,
#  'possible': 18815,
#  'dictates': 7444,
#  'humanity': 11698,
#  'crowned': 6523,
#  'depending': 7153,
#  'expeditions': 9289,
#  'whose': 26292,
#  'enterprise': 8818,
#  'intrepidity': 12918,
#  'commendation': 5436,
#  'continued': 6064,
#  'deluded': 7049,
#  'numbers': 17155,
#  'individuals': 12317,
#  'belonging': 3644,
#  'lately': 13613,
#  'renounced': 20573,
#  'opposition': 17536,
#  'removed': 20543,
#  'immediate': 11887,
#  'sincerely': 22295,
#  'coercion': 5276,
#  'future': 10457,
#  'cease': 4689,
#  'intimate': 12893,
#  'succeed': 23386,
#  'calculated': 4438,
#  'advance': 1955,
#  'firmly': 9864,
#  'order': 17567,
#  'experience': 9305,
#  'benefits': 3672,
#  'impartial': 11921,
#  'dispensation': 7788,
#  'alienating': 2216,
#  'lands': 13575,
#  'main': 14262,
#  'source': 22626,
#  'discontent': 7641,
#  'obviate': 17365,
#  'imposition': 12017,
#  'practicable': 18874,
#  'controversy': 6118,
#  'concerning': 5680,
#  'reality': 19903,
#  'extent': 9402,
#  'alienations': 2218,
#  'regulations': 20351,
#  'tending': 23996,
#  'equitable': 8924,
#  'deportment': 7182,
#  'rational': 19840,
#  'experiments': 9314,
#  'imparting': 11924,
#  'civilization': 5082,
#  'suit': 23447,
#  'condition': 5724,
#  'executive': 9200,
#  'enabled': 8607,
#  'employ': 8577,
#  'long': 14065,
#  'accustomed': 1754,
#  'preservation': 19041,
#  'efficacious': 8365,
#  'inflicting': 12439,
#  'penalties': 18224,
#  'violating': 25867,
#  'infringe': 12465,
#  'endanger': 8653,
#  'corresponding': 6273,
#  'mild': 14835,
#  'religion': 20462,
#  'philanthropy': 18462,
#  'unenlightened': 25134,
#  'race': 19715,
#  'materially': 14532,
#  'depends': 7154,
#  'conformable': 5792,
#  'sound': 22616,
#  'laying': 13674,
#  'duties': 8230,
#  ...}

# %%
doc_terms.shape
# Out:
# (220, 26682)
